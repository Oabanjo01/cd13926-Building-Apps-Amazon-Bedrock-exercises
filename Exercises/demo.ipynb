# %%
import boto3
import json

session = boto3.Session(profile_name='udacity')

# %%
client = session.client('bedrock-runtime', region_name='us-west-2')
model_id = "us.anthropic.claude-3-5-sonnet-20241022-v2:0"

# %%
identity = session.client("sts").get_caller_identity()
print(identity)
# Out:
# {'UserId': 'AROA5LUF534N5MA7CSEP7:user4516079=e584e7ac-ab7a-11ed-a49d-f724b5b93113', 'Account': '918330138395', 'Arn': 'arn:aws:sts::918330138395:assumed-role/voclabs/user4516079=e584e7ac-ab7a-11ed-a49d-f724b5b93113', 'ResponseMetadata': {'RequestId': '0a9dd4fa-f246-4d7d-b684-1ee5749b169f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '0a9dd4fa-f246-4d7d-b684-1ee5749b169f', 'x-amz-sts-extended-request-id': 'MTp1cy13ZXN0LTE6UzoxNzY0OTAxMzU2MTU5OlI6WUVzOEpKdkw=', 'content-type': 'text/xml', 'content-length': '510', 'date': 'Fri, 05 Dec 2025 02:22:36 GMT'}, 'RetryAttempts': 0}}

# %%
prompt_text = "Provide a recipe for making eba"

# %%
# Format the request payload using the model's native structure
request_body = {
    "anthropic_version": "bedrock-2023-05-31",
    "max_tokens": 1024,
    "temperature": 0.7,
    "messages": [
        {
            "role": "user",
            "content": [{"type": "text", "text": prompt_text}]
        }
    ]
}

# %%
# Invoke the model
response = client.invoke_model(
    modelId=model_id,
    body=json.dumps(request_body)
)

# %%
# Parse the response
response_body = json.loads(response['body'].read())
generated_text = response_body['content'][0]['text']
print(generated_text)
# Out:
# Here's a recipe for making Eba, a popular West African dish made from cassava flour (garri):
#
# Ingredients:
# - Cassava flour (garri)
# - Hot water
# - Cold water (room temperature)
# - Large bowl
# - Wooden spoon for stirring
#
# Instructions:
#
# 1. Boil water in a kettle or pot
#
# 2. Put some room temperature water in a large bowl (just enough to prevent the garri from forming lumps)
#
# 3. Gradually add the cassava flour (garri) to the cold water and stir briefly
#
# 4. Add hot water to the bowl while stirring continuously with a wooden spoon
#
# 5. Keep stirring vigorously to prevent lumps from forming
#
# 6. Continue adding garri and stirring until you achieve your desired consistency (it should be smooth and firm enough to mold)
#
# 7. Using the wooden spoon, knead the mixture until it becomes very smooth
#
# 8. Shape the Eba into balls or your preferred serving style
#
# Tips:
# - The ratio of garri to water depends on personal preference
# - The final consistency should be smooth and firm enough to pick up with your fingers
# - Serve hot with your favorite Nigerian soup (like Egusi, Okra, or Vegetable soup)
# - If it becomes too soft, add more garri; if too firm, add more hot water
#
# Note: The quality of garri used will affect the final taste and texture of your Eba.
